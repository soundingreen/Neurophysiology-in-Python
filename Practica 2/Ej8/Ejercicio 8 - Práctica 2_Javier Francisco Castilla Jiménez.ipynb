# %% [markdown]
# # Ejercicio 8 - Práctica 2
# ## Javier Franciso Castilla Jiménez

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import NeuralFunctJC as nrn

# %%
plt.style.use('seaborn-white')

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
#Cargar los datos
NeuDPC1=nrn.importar('TiemposNeuDPC1.txt')
NeuDPC2=nrn.importar('TiemposNeuDPC2.txt')
NeuS1=nrn.importar('TiemposNeuS1.txt')
NeuS1A=nrn.importar('TiemposNeuS1A.txt')
#De estas primeras 4 Neuronas ya sé que cada clase/bloque tiene 15 ensayos

# %%
Names=['NeuDPC1','NeuDPC2','NeuS1','NeuS1A']
hwpatron=[NeuDPC1,NeuDPC2,NeuS1,NeuS1A]
tipo=[' G-G',' G-E',' E-G',' E-E']

# %%
for i in range(len(Names)):
    neu=nrn.clases(hwpatron[i],(15,15,15,15))
    nrn.raster4plot(neu,Names[i]+'\n Tarea de discriminación de patrones temporales',tipo)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
#Cargar los datos
TS1A=nrn.import_between_v2('Neu_Det_S1A.csv',-2,3.5)
TS1B=nrn.import_between_v2('Neu_Det_S1B.csv',-2,3.5)
TS1C=nrn.import_between_v2('Neu_Det_S1C.csv',-2,3.5)
TS1D=nrn.import_between_v2('Neu_Det_S1D.csv',-2,3.5)
TS1E=nrn.import_between_v2('Neu_Det_S1E.csv',-2,3.5)
# De estas 5 neuronas no sé cuantos elementos tiene cada clase, solo que son 6 clases

# %%
bqA=list((nrn.bloques(nrn.abrir('Neu_Det_S1A.csv'))))
bqB=list((nrn.bloques(nrn.abrir('Neu_Det_S1B.csv'))))
bqC=list((nrn.bloques(nrn.abrir('Neu_Det_S1C.csv'))))
bqD=list((nrn.bloques(nrn.abrir('Neu_Det_S1D.csv'))))
bqE=list((nrn.bloques(nrn.abrir('Neu_Det_S1E.csv'))))

bqs=[bqA,bqB,bqC,bqD,bqE]

# %%
NamesDet=['Neu_Det_S1A','Neu_Det_S1B','Neu_Det_S1C','Neu_Det_S1D','Neu_Det_S1E']
hwdetection=[TS1A,TS1B,TS1C,TS1D,TS1E]

# %%
for i in range(len(NamesDet)):
    neu=nrn.clases(hwdetection[i],bqs[i])
    nrn.raster6plot(neu,NamesDet[i]+'\n Tarea de detección')
