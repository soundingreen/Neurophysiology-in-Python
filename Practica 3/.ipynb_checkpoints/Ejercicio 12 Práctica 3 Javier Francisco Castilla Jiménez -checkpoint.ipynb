# %% [markdown]
# # Ejercicio 12
# # Práctica 3
# # Javier Francisco Castilla Jiménez

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
